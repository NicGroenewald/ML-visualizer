# %% [markdown]
# # mlviz demo
#
# Each code cell below is standalone. Run any single cell to test one supported model/task combination.

# %% [markdown]
# ## Decision Tree Classifier

# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from mlviz import visualize

iris = load_iris()
X, y = iris.data, iris.target

model = DecisionTreeClassifier(max_depth=3, random_state=0)
model.fit(X, y)

visualize(
    model,
    X,
    y,
    query=X[0],
    feature_names=iris.feature_names,
    dataset_name="iris classification",
)

# %% [markdown]
# ## Decision Tree Regressor

# %%
from sklearn.datasets import load_diabetes
from sklearn.tree import DecisionTreeRegressor
from mlviz import visualize

diabetes = load_diabetes()
X, y = diabetes.data, diabetes.target

model = DecisionTreeRegressor(max_depth=3, random_state=0)
model.fit(X, y)

visualize(
    model,
    X,
    y,
    query=X[0],
    feature_names=diabetes.feature_names,
    dataset_name="diabetes regression",
)

# %% [markdown]
# ## Random Forest Classifier

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.ensemble import RandomForestClassifier
from mlviz import visualize

breast = load_breast_cancer()
X, y = breast.data, breast.target

model = RandomForestClassifier(
    n_estimators=50,
    max_depth=4,
    random_state=0,
    bootstrap=True,
    oob_score=True,
)
model.fit(X, y)

visualize(
    model,
    X,
    y,
    query=X[0],
    feature_names=breast.feature_names,
    dataset_name="breast cancer classification",
)

# %% [markdown]
# ## Random Forest Regressor

# %%
from sklearn.datasets import load_diabetes
from sklearn.ensemble import RandomForestRegressor
from mlviz import visualize

diabetes = load_diabetes()
X, y = diabetes.data, diabetes.target

model = RandomForestRegressor(
    n_estimators=50,
    max_depth=4,
    random_state=0,
    bootstrap=True,
    oob_score=True,
)
model.fit(X, y)

visualize(
    model,
    X,
    y,
    query=X[0],
    feature_names=diabetes.feature_names,
    dataset_name="diabetes regression forest",
)

# %% [markdown]
# ## KNN Classifier

# %%
from sklearn.datasets import load_iris
from sklearn.neighbors import KNeighborsClassifier
from mlviz import visualize

iris = load_iris()
X, y = iris.data, iris.target

model = KNeighborsClassifier(n_neighbors=5, weights="distance")
model.fit(X, y)

visualize(
    model,
    X,
    y,
    query=X[0],
    feature_names=iris.feature_names,
    dataset_name="iris knn classification",
)

# %% [markdown]
# ## KNN Regressor

# %%
from sklearn.datasets import load_diabetes
from sklearn.neighbors import KNeighborsRegressor
from mlviz import visualize

diabetes = load_diabetes()
X, y = diabetes.data, diabetes.target

model = KNeighborsRegressor(n_neighbors=5, weights="distance")
model.fit(X, y)

visualize(
    model,
    X,
    y,
    query=X[0],
    feature_names=diabetes.feature_names,
    dataset_name="diabetes knn regression",
)

# %% [markdown]
# ## SVM Classifier

# %%
from sklearn.datasets import load_iris
from sklearn.svm import SVC
from mlviz import visualize

iris = load_iris()
X, y = iris.data, iris.target

model = SVC(kernel="rbf", probability=True, random_state=0)
model.fit(X, y)

visualize(
    model,
    X,
    y,
    query=X[0],
    feature_names=iris.feature_names,
    dataset_name="iris svm classification",
)

# %% [markdown]
# ## SVM Regressor

# %%
from sklearn.datasets import load_diabetes
from sklearn.svm import SVR
from mlviz import visualize

diabetes = load_diabetes()
X, y = diabetes.data, diabetes.target

model = SVR(kernel="rbf", C=10.0, epsilon=0.2)
model.fit(X, y)

visualize(
    model,
    X,
    y,
    query=X[0],
    feature_names=diabetes.feature_names,
    dataset_name="diabetes svm regression",
)

# %% [markdown]
# ## Your own model

# %%
# from sklearn.tree import DecisionTreeClassifier
# from mlviz import visualize

# X_train = ...
# y_train = ...
# feature_names = [...]
# query = X_train[0]

# model = DecisionTreeClassifier(max_depth=4)
# model.fit(X_train, y_train)

# visualize(model, X_train, y_train, query=query, feature_names=feature_names, dataset_name="my dataset")
